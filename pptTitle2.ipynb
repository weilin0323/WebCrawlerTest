# %%
import requests
from bs4 import BeautifulSoup 

r = requests.Session()
payload ={
    "from":"/bbs/Gossiping/index.html",
    "yes":"yes"
}
r1 = r.post("https://www.ptt.cc/ask/over18?from=%2Fbbs%2FGossiping%2Findex.html",payload)
r2 = r.get("https://www.ptt.cc/bbs/Gossiping/index.html")
print(r2.text)
# Out:
# 練習來源:https://ithelp.ithome.com.tw/articles/10202493
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# ...

# %%
soup = BeautifulSoup(r2.text,"html.parser") #將網頁資料以html.parser
sel = soup.select("div.title a") #取HTML標中的 <div class="title"></div> 中的<a>標籤存入sel
print("練習來源:https://ithelp.ithome.com.tw/articles/10202493")
for s in sel:
    print(s["href"], s.text)
# Out:
# 練習來源:https://ithelp.ithome.com.tw/articles/10202493
# /bbs/Gossiping/M.1626184507.A.049.html [問卦] XX年一遇的美少女有比較香嗎?
# /bbs/Gossiping/M.1626184523.A.91B.html [問卦] A片也要做好防疫措施
# /bbs/Gossiping/M.1626184570.A.38A.html [問卦] 現役可愛JK也來拍YT了？
# /bbs/Gossiping/M.1626184596.A.C89.html [問卦] 台積電和郭董的疫苗上面要貼什麼?
# /bbs/Gossiping/M.1626184643.A.BA3.html [問卦] 我們是被割韭菜的一群
# /bbs/Gossiping/M.1626184645.A.047.html Re: [新聞] 指「同志團體是問題」挨轟 柯文哲未道歉
# /bbs/Gossiping/M.1626184649.A.E9F.html [問卦] “急 在線等” 各神奇寶貝名字
# /bbs/Gossiping/M.1626184679.A.53D.html [問卦] 減肥期間晚上吃什麼才好
# /bbs/Gossiping/M.1626184710.A.0C9.html [問卦] 1450 意願登記沒有國產可以選
# /bbs/Gossiping/M.1626184751.A.4C1.html [問卦] 國產疫苗做不出來，會有人切腹自殺嗎
# /bbs/Gossiping/M.1620716589.A.F0C.html [公告] 八卦板板規(2021.05.11)
# /bbs/Gossiping/M.1626004276.A.2BA.html [協尋] 20210709二侖自強果菜市場
# /bbs/Gossiping/M.1625823187.A.096.html [協尋] 徵7/8中和區連城路上午8點行車紀錄器
# /bbs/Gossiping/M.1626066832.A.983.html [協尋] 徵求桃園市大溪路大鶯路行車記錄
# /bbs/Gossiping/M.1626109162.A.AB2.html [協尋] 7/9中午八德路四段245巷行車紀錄器
